# %%
# !pip install pycaret

# %%
# !pip install markupsafe==2.0.1

# %%
from pycaret.regression import *
# Out:
# /usr/local/lib/python3.7/dist-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
train = pd.read_csv('./drive/MyDrive/LG_Aimer/train.csv')
test = pd.read_csv('./drive/MyDrive/LG_Aimer/test.csv')
meta_x_features= pd.read_csv('./drive/MyDrive/LG_Aimer/meta/x_feature_info.csv')
meta_y_features= pd.read_csv('./drive/MyDrive/LG_Aimer/meta/y_feature_info.csv')

from sklearn.linear_model import LinearRegression
from sklearn.multioutput import MultiOutputRegressor
import random
import os
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED']=str(seed)
    np.random.seed(seed)
seed_everything(42)

# %%
train_df = train.copy()
train_df = train_df.drop('ID',axis=1,inplace=False)
train_x = train_df.filter(regex='X') # Input : X Featrue
train_y = train_df.filter(regex='Y') # Output : Y Feature

# %%
train_01 = pd.concat([train_x, train_y['Y_01']], axis=1)
train_02 = pd.concat([train_x, train_y['Y_02']], axis=1)
train_03 = pd.concat([train_x, train_y['Y_03']], axis=1)
train_04 = pd.concat([train_x, train_y['Y_04']], axis=1)
train_05 = pd.concat([train_x, train_y['Y_05']], axis=1)
train_06 = pd.concat([train_x, train_y['Y_06']], axis=1)
train_07 = pd.concat([train_x, train_y['Y_07']], axis=1)
train_08 = pd.concat([train_x, train_y['Y_08']], axis=1)
train_09 = pd.concat([train_x, train_y['Y_09']], axis=1)
train_10 = pd.concat([train_x, train_y['Y_10']], axis=1)
train_11 = pd.concat([train_x, train_y['Y_11']], axis=1)
train_12 = pd.concat([train_x, train_y['Y_12']], axis=1)
train_13 = pd.concat([train_x, train_y['Y_13']], axis=1)
train_14 = pd.concat([train_x, train_y['Y_14']], axis=1)

# %%
train_df

# %%
train_column = ['X_01', 'X_02', 'X_03', 'X_04', 'X_05', 'X_06', 'X_07', 'X_08', 'X_09',
       'X_10', 'X_11', 'X_12', 'X_13', 'X_14', 'X_15', 'X_16', 'X_17', 'X_18',
       'X_19', 'X_20', 'X_21', 'X_22', 'X_23', 'X_24', 'X_25', 'X_26', 'X_27',
       'X_28', 'X_29', 'X_30', 'X_31', 'X_32', 'X_33', 'X_34', 'X_35', 'X_36',
       'X_37', 'X_38', 'X_39', 'X_40', 'X_41', 'X_42', 'X_43', 'X_44', 'X_45',
       'X_46', 'X_47', 'X_48', 'X_49', 'X_50', 'X_51', 'X_52', 'X_53', 'X_54',
       'X_55', 'X_56']

# %%
model = setup(train_01, target = 'Y_01', session_id=42,numeric_features=train_column)
# Out:
#                                Description             Value
# 0                               session_id                42
# 1                                   Target              Y_01
# 2                            Original Data       (39607, 57)
# 3                           Missing Values             False
# 4                         Numeric Features                56
# 5                     Categorical Features                 0
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set       (27724, 56)
# 10                    Transformed Test Set       (11883, 56)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...

# %%
compare_models()
# Out:
#                                     Model     MAE     MSE    RMSE      R2  \
# gbr           Gradient Boosting Regressor  0.2682  0.1204  0.3470  0.0462
# rf                Random Forest Regressor  0.2685  0.1205  0.3471  0.0457
# lightgbm  Light Gradient Boosting Machine  0.2687  0.1205  0.3471  0.0454
# et                  Extra Trees Regressor  0.2689  0.1209  0.3477  0.0424
# ridge                    Ridge Regression  0.2706  0.1224  0.3499  0.0301
# br                         Bayesian Ridge  0.2708  0.1226  0.3501  0.0292
# omp           Orthogonal Matching Pursuit  0.2724  0.1240  0.3521  0.0178
# ada                    AdaBoost Regressor  0.2739  0.1247  0.3531  0.0124
# lr                      Linear Regression  0.2728  0.1248  0.3532  0.0117
# lasso                    Lasso Regression  0.2747  0.1260  0.3550  0.0016
# en                            Elastic Net  0.2747  0.1261  0.3550  0.0015
# llar         Lasso Least Angle Regression  0.2749  0.1263  0.3553 -0.0003
# ...

# %%
model = setup(train_02, target = 'Y_02', session_id=42,numeric_features=train_column)
compare_models()
# Out:
#                                     Model     MAE     MSE    RMSE      R2  \
# gbr           Gradient Boosting Regressor  0.2974  0.1426  0.3777  0.0387
# rf                Random Forest Regressor  0.2980  0.1428  0.3778  0.0380
# lightgbm  Light Gradient Boosting Machine  0.2977  0.1430  0.3781  0.0366
# et                  Extra Trees Regressor  0.2989  0.1436  0.3789  0.0323
# ridge                    Ridge Regression  0.2991  0.1439  0.3794  0.0300
# br                         Bayesian Ridge  0.2993  0.1441  0.3796  0.0289
# omp           Orthogonal Matching Pursuit  0.3007  0.1451  0.3809  0.0222
# lr                      Linear Regression  0.3008  0.1462  0.3824  0.0145
# lar                Least Angle Regression  0.3017  0.1468  0.3831  0.0109
# lasso                    Lasso Regression  0.3041  0.1483  0.3851  0.0005
# en                            Elastic Net  0.3041  0.1483  0.3851  0.0005
# llar         Lasso Least Angle Regression  0.3043  0.1485  0.3854 -0.0009
# ...

# %%
model = setup(train_03, target = 'Y_03', session_id=42,numeric_features=train_column)
compare_models()
# Out:
#                                     Model     MAE     MSE    RMSE      R2  \
# gbr           Gradient Boosting Regressor  0.2789  0.1258  0.3546  0.0351
# lightgbm  Light Gradient Boosting Machine  0.2789  0.1259  0.3548  0.0341
# rf                Random Forest Regressor  0.2792  0.1260  0.3549  0.0337
# et                  Extra Trees Regressor  0.2796  0.1263  0.3554  0.0311
# ridge                    Ridge Regression  0.2803  0.1271  0.3565  0.0249
# br                         Bayesian Ridge  0.2805  0.1273  0.3567  0.0236
# omp           Orthogonal Matching Pursuit  0.2818  0.1282  0.3581  0.0164
# lr                      Linear Regression  0.2817  0.1287  0.3587  0.0129
# lar                Least Angle Regression  0.2823  0.1288  0.3589  0.0121
# lasso                    Lasso Regression  0.2842  0.1302  0.3608  0.0014
# en                            Elastic Net  0.2841  0.1302  0.3608  0.0014
# llar         Lasso Least Angle Regression  0.2844  0.1304  0.3611 -0.0006
# ...

# %%
model = setup(train_04, target = 'Y_04', session_id=42,numeric_features=train_column)
compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# rf                Random Forest Regressor  2.0666   6.4939  2.5480  0.0731
# lightgbm  Light Gradient Boosting Machine  2.0751   6.5484  2.5587  0.0653
# et                  Extra Trees Regressor  2.0809   6.5627  2.5614  0.0633
# gbr           Gradient Boosting Regressor  2.0922   6.6288  2.5744  0.0539
# ridge                    Ridge Regression  2.1177   6.7707  2.6018  0.0336
# br                         Bayesian Ridge  2.1180   6.7716  2.6020  0.0335
# lar                Least Angle Regression  2.1186   6.7873  2.6050  0.0312
# lr                      Linear Regression  2.1198   6.7901  2.6055  0.0308
# omp           Orthogonal Matching Pursuit  2.1322   6.8578  2.6184  0.0212
# lasso                    Lasso Regression  2.1572   7.0068  2.6468 -0.0001
# en                            Elastic Net  2.1572   7.0071  2.6469 -0.0002
# ...

# %%
model = setup(train_05, target = 'Y_05', session_id=42,numeric_features=train_column)
compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# lightgbm  Light Gradient Boosting Machine  1.9846   6.2316  2.4961  0.0330
# gbr           Gradient Boosting Regressor  1.9896   6.2518  2.5001  0.0300
# rf                Random Forest Regressor  2.0022   6.2765  2.5050  0.0261
# et                  Extra Trees Regressor  2.0042   6.2864  2.5070  0.0246
# br                         Bayesian Ridge  2.0017   6.3087  2.5114  0.0212
# ridge                    Ridge Regression  2.0023   6.3118  2.5120  0.0207
# omp           Orthogonal Matching Pursuit  2.0172   6.4012  2.5298  0.0068
# en                            Elastic Net  2.0236   6.4406  2.5375  0.0007
# lasso                    Lasso Regression  2.0236   6.4411  2.5377  0.0006
# llar         Lasso Least Angle Regression  2.0252   6.4483  2.5391 -0.0005
# dummy                     Dummy Regressor  2.0252   6.4483  2.5391 -0.0005
# ...

# %%
model = setup(train_06, target = 'Y_06', session_id=42,numeric_features=train_column)
compare_models()
# Out:
#                                     Model     MAE     MSE    RMSE      R2  \
# lightgbm  Light Gradient Boosting Machine  0.7576  3.2431  1.7939  0.0861
# rf                Random Forest Regressor  0.7489  3.3864  1.8334  0.0471
# et                  Extra Trees Regressor  0.7427  3.4254  1.8419  0.0419
# gbr           Gradient Boosting Regressor  0.7409  3.5037  1.8640  0.0176
# ridge                    Ridge Regression  0.7232  3.5519  1.8751  0.0088
# br                         Bayesian Ridge  0.7212  3.5596  1.8770  0.0069
# omp           Orthogonal Matching Pursuit  0.7234  3.5680  1.8792  0.0045
# lasso                    Lasso Regression  0.7140  3.5857  1.8836  0.0003
# en                            Elastic Net  0.7142  3.5856  1.8836  0.0003
# lar                Least Angle Regression  0.7425  3.5817  1.8832  0.0000
# llar         Lasso Least Angle Regression  0.7131  3.5878  1.8841 -0.0003
# dummy                     Dummy Regressor  0.7131  3.5878  1.8841 -0.0003
# ...

# %%
model = setup(train_07, target = 'Y_07', session_id=42,numeric_features=train_column)
compare_models()
# Out:
#                                     Model     MAE     MSE    RMSE      R2  \
# rf                Random Forest Regressor  0.3257  0.1677  0.4095  0.0395
# lightgbm  Light Gradient Boosting Machine  0.3259  0.1679  0.4097  0.0384
# et                  Extra Trees Regressor  0.3265  0.1687  0.4108  0.0334
# gbr           Gradient Boosting Regressor  0.3268  0.1689  0.4110  0.0323
# ridge                    Ridge Regression  0.3279  0.1702  0.4125  0.0253
# br                         Bayesian Ridge  0.3280  0.1702  0.4126  0.0249
# lar                Least Angle Regression  0.3280  0.1704  0.4127  0.0240
# lr                      Linear Regression  0.3282  0.1704  0.4128  0.0238
# omp           Orthogonal Matching Pursuit  0.3293  0.1712  0.4138  0.0191
# lasso                    Lasso Regression  0.3330  0.1747  0.4180 -0.0008
# en                            Elastic Net  0.3330  0.1747  0.4180 -0.0008
# llar         Lasso Least Angle Regression  0.3330  0.1747  0.4180 -0.0009
# ...

# %%
# mse 성능평가
# Y_1
# gbr 0.1204
# rf 0.1205
# lightgbm 0.1205

# Y_2
# gbr 0.1426
# rf 0.1428
# lightgbm 0.1430

# Y_3
# gbr 0.1258
# lightgbm 0.1259
# rf 0.1260

# Y_4
# rf 6.4939
# lightgbm 6.5484
# et 6.5627

# Y_5
# lightgbm 6.2316
# gbr 6.2518
# rf 6.2765

# Y_6
# lightgbm 3.2431
# rf 3.3864
# et 3.4254

# Y_7
# rf 0.1677
# lightgbm 0.1679
# et 0.1687
