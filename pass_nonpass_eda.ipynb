# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
train = pd.read_csv('./drive/MyDrive/LG_Aimer/train.csv')
test = pd.read_csv('./drive/MyDrive/LG_Aimer/test.csv')
meta_x_features= pd.read_csv('./drive/MyDrive/LG_Aimer/meta/x_feature_info.csv')
meta_y_features= pd.read_csv('./drive/MyDrive/LG_Aimer/meta/y_feature_info.csv')

from sklearn.linear_model import LinearRegression
from sklearn.multioutput import MultiOutputRegressor
import random
import os
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED']=str(seed)
    np.random.seed(seed)
seed_everything(42)

# %%
meta_y_features
# Out:
#    Feature                   설명
# 0     Y_01  안테나 Gain 평균 (각도1)
# 1     Y_02        안테나 1 Gain 편차
# 2     Y_03        안테나 2 Gain 편차
# 3     Y_04          평균 신호대 잡음비
# 4     Y_05    안테나 Gain 평균 (각도2)
# 5     Y_06     신호대 잡음비  (각도1)
# 6     Y_07  안테나 Gain 평균 (각도3)
# 7     Y_08     신호대 잡음비  (각도2)
# 8     Y_09     신호대 잡음비  (각도3)
# 9     Y_10     신호대 잡음비  (각도4)
# 10    Y_11    안테나 Gain 평균 (각도4)
# 11    Y_12     신호대 잡음비  (각도5)
# 12    Y_13     신호대 잡음비  (각도6)
# 13    Y_14     신호대 잡음비  (각도7)

# %%
df = pd.read_csv('./drive/MyDrive/LG_Aimer/train.csv')

# %%
df1 = df.copy()
df1=df[(df['Y_01']>=0.2)&(df['Y_01']<2.0)&(df['Y_02']>=0.2)
&(df['Y_02']<=2.1)&(df['Y_02']>=0.2)
&(df['Y_03']>=0.2)&(df['Y_03']<=2.1)
&(df['Y_04']<=19)&(df['Y_04']>=7)&(df['Y_05']<=36.5)&(df['Y_05']>=22)
&(df['Y_06']>=-19.2)&(df['Y_06']<=19)&(df['Y_07']>=2.4)&(df['Y_07']<=4)
&(df['Y_08']>=-29.2)&(df['Y_08']<=-24)&(df['Y_09']>=-29.2)&(df['Y_09']<=-24)
&(df['Y_10']>=-30.6)&(df['Y_10']<=-20)&(df['Y_11']>=19.6)&(df['Y_11']<=26.6)
&(df['Y_12']>=-29.2)&(df['Y_12']<=-24)&(df['Y_13']>=-29.2)&(df['Y_13']<=-24)
&(df['Y_14']>=-29.2)&(df['Y_14']<=-24)]
len(df1.index)
# Out:
# 35687

# %%
for idx in range(0,39607):
    if idx in df1.index:
        df.loc[idx,'pass']=1
    else:
        df.loc[idx,'pass']=0
df['pass'].value_counts()
# Out:
# 1.0    35687
# 0.0     3920
# Name: pass, dtype: int64

# %%
df[['X_19','X_20','X_21','X_22','pass']]
# Out:
#        X_19  X_20  X_21  X_22  pass
# 0      3.11  3.17  3.06  3.13   0.0
# 1      2.97  3.11  2.91  3.20   1.0
# 2      3.04  3.04  3.01  3.12   1.0
# 3      3.05  3.01  3.02  3.08   1.0
# 4      3.04  3.07  3.00  3.12   1.0
# ...     ...   ...   ...   ...   ...
# 39602  3.20  3.03  3.06  3.13   1.0
# 39603  3.15  3.06  3.05  3.06   1.0
# 39604  3.23  3.09  3.07  3.12   1.0
# 39605  3.18  3.01  3.15  3.09   0.0
# 39606  3.11  3.05  3.03  3.10   1.0
#
# [39607 rows x 5 columns]

# %%
max = df.loc[:,['X_19','X_20','X_21','X_22']].max(axis=1)
min = df.loc[:,['X_19','X_20','X_21','X_22']].min(axis=1)
df['X_60'] = max-min

# %%
max = df.loc[:,['X_29','X_30','X_31','X_32']].max(axis=1)
min = df.loc[:,['X_29','X_30','X_31','X_32']].min(axis=1)
df['X_61'] = max-min

# %%
df['X_60']
# Out:
# 0        0.11
# 1        0.29
# 2        0.11
# 3        0.07
# 4        0.12
#          ...
# 39602    0.17
# 39603    0.10
# 39604    0.16
# 39605    0.17
# 39606    0.08
# Name: X_60, Length: 39607, dtype: float64

# %%
df_pass = df[df['pass']==1.0]    
df_nonpass = df[df['pass']==0.0]

# %%
cor_pass = df_pass.corr(method='pearson')
xycor_pass = cor_pass.drop(columns=['X_04', 'X_23', 'X_47', 'X_48','pass']).filter(regex='X').filter(regex='Y', axis=0)

# %%
xycor_pass
# Out:
#           X_01      X_02      X_03      X_05      X_06      X_07      X_08  \
# Y_01  0.027759 -0.010252  0.013305 -0.007035  0.047784 -0.020896  0.005812
# Y_02  0.033695 -0.012685  0.082125 -0.009185  0.063233 -0.003012  0.013344
# Y_03 -0.009042 -0.005891  0.011304 -0.039180  0.036112  0.001577  0.015001
# Y_04  0.051798 -0.001694  0.009247  0.039808  0.038073 -0.001310 -0.017187
# Y_05  0.004859 -0.010772  0.000309 -0.002596  0.017262 -0.003835 -0.001120
# Y_06 -0.010972 -0.005073  0.013505  0.002048 -0.000339 -0.002255 -0.008065
# Y_07 -0.033514  0.008503 -0.009644 -0.017774 -0.025913  0.004878  0.008340
# Y_08  0.072795 -0.013660  0.132478  0.035170  0.078916 -0.015576 -0.003006
# Y_09  0.068063 -0.014891  0.119779  0.033355  0.072506 -0.018072 -0.003703
# Y_10  0.037199 -0.008003  0.143472 -0.009537  0.083534 -0.015499  0.009945
# Y_11  0.002984 -0.008159  0.033258  0.010950  0.009687 -0.004020 -0.008054
# Y_12  0.068655 -0.014452  0.123132  0.033495  0.075663 -0.016137 -0.003322
# Y_13  0.069458 -0.013634  0.124201  0.034294  0.075230 -0.016544 -0.005056
# Y_14  0.068552 -0.013183  0.120465  0.034418  0.074258 -0.017760 -0.004919
#
#           X_09      X_10      X_11  ...      X_49      X_50      X_51  \
# Y_01  0.019447  0.011550  0.011040  ...  0.041419  0.035416  0.059618
# Y_02 -0.017605  0.004137  0.003527  ...  0.036287  0.025577  0.042687
# Y_03  0.009137  0.014009  0.010121  ...  0.044687  0.024476  0.041266
# Y_04  0.002042 -0.005632 -0.004913  ...  0.010432  0.028365  0.027173
# Y_05  0.025756 -0.004727 -0.004466  ...  0.028620  0.030809  0.024695
# Y_06 -0.016196 -0.014431 -0.014029  ...  0.006547  0.031570  0.031488
# Y_07 -0.006011  0.003363 -0.000761  ... -0.024205 -0.018372 -0.014913
# Y_08 -0.001123 -0.017501 -0.017821  ...  0.007959  0.007798  0.048508
# Y_09 -0.001161 -0.015753 -0.016313  ...  0.007782  0.009572  0.047788
# Y_10  0.035225 -0.009460 -0.009570  ...  0.058905  0.023601  0.069555
# Y_11 -0.007654 -0.015853 -0.015280  ...  0.005283  0.029710  0.034743
# Y_12 -0.001616 -0.015400 -0.015982  ...  0.008600  0.010292  0.049646
# Y_13  0.000240 -0.016596 -0.016615  ...  0.008525  0.011036  0.049738
# Y_14 -0.000843 -0.014391 -0.015273  ...  0.007891  0.012047  0.052066
#
#           X_52      X_53      X_54      X_55      X_56      X_60      X_61
# Y_01  0.056278  0.045381  0.031868  0.033577  0.041459  0.037159  0.008554
# Y_02  0.025481  0.030945  0.024554 -0.005061  0.030448  0.052061 -0.004714
# Y_03  0.031753  0.022947  0.023564  0.017986  0.035477  0.041819  0.030850
# Y_04  0.020810  0.024608 -0.023356 -0.012113  0.014058 -0.000356 -0.061568
# Y_05  0.017554  0.029954 -0.007138 -0.002502  0.041201  0.010283 -0.039119
# Y_06  0.027909  0.024001  0.012182  0.005599  0.028438 -0.001239 -0.004139
# Y_07  0.013659 -0.001584  0.016428  0.018777 -0.013034 -0.020757  0.052144
# Y_08  0.013531  0.044136  0.002543 -0.037488  0.002961  0.008089 -0.069859
# Y_09  0.013867  0.043318  0.002906 -0.034367  0.002887  0.004791 -0.065845
# Y_10  0.027470  0.054885  0.007345 -0.020392  0.031544  0.037621 -0.076206
# Y_11  0.028150  0.028917  0.008317  0.002151  0.029346  0.000600 -0.016586
# Y_12  0.014295  0.043919  0.004913 -0.032984  0.005912  0.004316 -0.067852
# Y_13  0.013965  0.044294  0.004814 -0.033239  0.003735  0.005180 -0.066618
# Y_14  0.017392  0.046323  0.005210 -0.030716  0.005593  0.005896 -0.067689
#
# [14 rows x 54 columns]

# %%
cor_threshold = 0.5
cor_pass_abs = xycor_pass.abs()
cor_s = cor_pass_abs.unstack()
print(cor_s)
# Out:
# X_01  Y_01    0.027759
#       Y_02    0.033695
#       Y_03    0.009042
#       Y_04    0.051798
#       Y_05    0.004859
#                 ...
# X_61  Y_10    0.076206
#       Y_11    0.016586
#       Y_12    0.067852
#       Y_13    0.066618
#       Y_14    0.067689
# Length: 756, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (40,7)
sns.heatmap(xycor_pass.abs(),
           annot = True, #실제 값 화면에 나타내기
           cmap = 'Reds', #색상
          )

# %%
cor_nonpass = df_nonpass.corr(method='pearson')
xycor_nonpass = cor_nonpass.drop(columns=['X_04', 'X_23', 'X_47', 'X_48','pass']).filter(regex='X').filter(regex='Y', axis=0)

# %%
xycor_nonpass
# Out:
#           X_01      X_02      X_03      X_05      X_06      X_07      X_08  \
# Y_01  0.059625  0.010801  0.004305  0.040315  0.023686 -0.026332  0.022583
# Y_02  0.055117 -0.005077  0.048878  0.035463  0.028663 -0.023449  0.020695
# Y_03  0.036999  0.007883  0.011001  0.024795  0.021222 -0.024640  0.016459
# Y_04  0.054201  0.003687  0.003489  0.026435  0.041194 -0.017083 -0.021965
# Y_05  0.045301  0.004140  0.013479 -0.004597  0.053569  0.001543 -0.005894
# Y_06 -0.025730 -0.008567 -0.135891  0.038827 -0.110129 -0.027851  0.010033
# Y_07 -0.067942 -0.017124 -0.082746 -0.024168 -0.063689 -0.002950 -0.004060
# Y_08  0.055680 -0.011711  0.041977  0.020396  0.040989 -0.018957 -0.021238
# Y_09  0.045768 -0.010246  0.037214  0.013301  0.036879 -0.015465 -0.022717
# Y_10  0.014680 -0.008983 -0.032507  0.026995 -0.029175 -0.032852  0.001779
# Y_11  0.037756 -0.001384  0.036324  0.006902  0.030260  0.002153 -0.014612
# Y_12  0.047917 -0.007531  0.039631  0.012860  0.038535 -0.017031 -0.029027
# Y_13  0.051597 -0.008205  0.037117  0.013733  0.038243 -0.016681 -0.027768
# Y_14  0.050002 -0.012498  0.040320  0.015023  0.040811 -0.017046 -0.027552
#
#           X_09      X_10      X_11  ...      X_49      X_50      X_51  \
# Y_01  0.018418 -0.005631  0.004100  ...  0.051920  0.043948  0.053857
# Y_02  0.003658  0.013518  0.014244  ...  0.033716  0.016713  0.029941
# Y_03  0.017958  0.001240  0.007053  ...  0.046878  0.023682  0.034268
# Y_04 -0.017280 -0.015835 -0.005050  ...  0.037710  0.038596  0.049307
# Y_05 -0.004279 -0.027212 -0.010283  ...  0.018580  0.035480  0.044246
# Y_06  0.065395 -0.000012  0.002990  ...  0.064842  0.059406  0.043958
# Y_07  0.046430  0.015396  0.012217  ...  0.028255  0.011440  0.045913
# Y_08  0.025794 -0.022638 -0.002597  ...  0.025273  0.046939  0.072463
# Y_09  0.021528 -0.019218  0.001830  ...  0.026993  0.039896  0.065075
# Y_10  0.072616 -0.014565 -0.002512  ...  0.075996  0.073111  0.076903
# Y_11  0.013423 -0.025720 -0.008809  ...  0.009880  0.036069  0.034432
# Y_12  0.028858 -0.023205 -0.004597  ...  0.027611  0.041768  0.066761
# Y_13  0.031453 -0.022606 -0.002798  ...  0.027360  0.045458  0.070478
# Y_14  0.031165 -0.019622  0.001445  ...  0.027580  0.047082  0.071438
#
#           X_52      X_53      X_54      X_55      X_56      X_60      X_61
# Y_01  0.072428  0.043950  0.039755  0.018758  0.056246  0.046964 -0.036367
# Y_02  0.042235  0.018153  0.030302 -0.001616  0.044686  0.070627 -0.040221
# Y_03  0.051194  0.028286  0.032374  0.009127  0.048921  0.051440 -0.018652
# Y_04  0.016244  0.016068 -0.025446 -0.049545  0.020252 -0.003559 -0.052541
# Y_05  0.015914 -0.006449 -0.019097 -0.042447  0.036627  0.032336 -0.030330
# Y_06  0.042952  0.038635  0.064697  0.049465  0.083876 -0.005049 -0.055085
# Y_07  0.071134  0.062409  0.079895  0.128052  0.036150 -0.062101  0.015939
# Y_08  0.050259  0.035301  0.013429 -0.012310  0.059106  0.021893 -0.079160
# Y_09  0.048915  0.029183  0.008477 -0.009145  0.052235  0.016140 -0.072737
# Y_10  0.061150  0.059378  0.051687  0.027171  0.098841  0.020355 -0.084947
# Y_11  0.031244  0.007474 -0.013328 -0.027058  0.048120  0.029001 -0.024940
# Y_12  0.049466  0.031377  0.009902 -0.011485  0.054117  0.016941 -0.070908
# Y_13  0.053891  0.033110  0.012174 -0.008065  0.055226  0.016760 -0.071741
# Y_14  0.053804  0.034255  0.012840 -0.008336  0.057602  0.015962 -0.068902
#
# [14 rows x 54 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (40,7)
sns.heatmap(xycor_nonpass.abs(),
           annot = True, #실제 값 화면에 나타내기
           cmap = 'Reds', #색상
          )

# %%
df_pass = df[df['pass']==1.0]    
df_nonpass = df[df['pass']==0.0]

# %%
drop_sensors = ['ID','X_04', 'X_23', 'X_47', 'X_48','Y_01', 'Y_02', 'Y_03', 'Y_04', 'Y_05', 'Y_06', 'Y_07', 'Y_08', 'Y_09',
       'Y_10', 'Y_11', 'Y_12', 'Y_13', 'Y_14','pass']
df_pass = df_pass.drop(labels = drop_sensors,axis=1, inplace=False)
df_nonpass = df_nonpass.drop(labels = drop_sensors,axis=1, inplace=False)
print(df_pass.shape, df_nonpass.shape)
# Out:
# (35687, 54) (3920, 54)

# %%
df_pass
# Out:
#          X_01     X_02   X_03     X_05    X_06   X_07    X_08    X_09  X_10  \
# 1      69.524  103.321  65.17  101.944  72.943  28.73   61.23  233.61   0.0
# 2      72.583  103.320  64.07  103.153  72.943  28.81  105.77  272.20   0.0
# 3      71.563  103.320  67.57  101.971  77.022  28.92  115.21  255.36   0.0
# 4      69.524  103.320  63.57  101.981  70.904  29.68  103.38  241.46   0.0
# 5      69.524  103.320  62.77  101.899  69.884  27.90   64.97  241.85   0.0
# ...       ...      ...    ...      ...     ...    ...     ...     ...   ...
# 39601  64.425  103.320  63.87  102.037  68.864  30.40   99.99  199.55   0.0
# 39602  66.465  103.320  62.27  103.150  66.825  30.20   77.83  298.05   0.0
# 39603  66.465  103.321  62.77  102.021  66.825  29.21  102.25  270.67   0.0
# 39604  68.504  103.320  64.67  103.144  68.864  29.96  102.61  198.07   0.0
# 39606  66.465  103.320  65.67  102.004  69.884  30.16  112.90  276.06   0.0
#
#        X_11  ...      X_49        X_50        X_51        X_52        X_53  \
# 1       0.0  ...  10423.43  133.736691  135.979817  149.924692  123.630583
# 2       0.0  ...  10948.53  132.805112  131.055355  146.814592  128.939070
# 3       0.0  ...  15007.03  134.138760  133.239422  139.720132  132.260824
# 4       0.0  ...  11051.03  142.728970  136.620022  134.853555  134.760252
# 5       0.0  ...   9514.23  137.649365  124.373890  145.751970  121.860937
# ...     ...  ...       ...         ...         ...         ...         ...
# 39601   0.0  ...  60707.83  128.922673  128.715023  137.359163  125.521040
# 39602   0.0  ...  60630.73  129.965741  130.807148  133.481737  125.273130
# 39603   0.0  ...  60763.43  127.633885  120.158764  142.667802  122.465490
# 39604   0.0  ...   8813.33  132.501286  136.893025  134.419328  129.115431
# 39606   0.0  ...  62172.23  135.096272  122.988476  142.019357  123.752157
#
#              X_54        X_55        X_56  X_60  X_61
# 1      127.893337  143.322659  124.877308  0.29  0.83
# 2      127.012195  140.395688  122.238232  0.11  0.80
# 3      130.723186  147.624829  134.875225  0.07  0.65
# 4      125.647793  139.331105  123.272762  0.12  0.66
# 5      127.081180  139.840405  123.946308  0.06  0.70
# ...           ...         ...         ...   ...   ...
# 39601  130.121288  138.584111  121.000820  0.08  0.78
# 39602  121.780933  133.780110  129.029812  0.17  0.84
# 39603  122.987209  143.090741  122.811413  0.10  0.83
# 39604  130.920147  140.489232  119.166699  0.16  0.79
# 39606  130.648365  139.695370  136.714504  0.08  0.81
#
# [35687 rows x 54 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
pass_scaled = scaler.fit_transform(df_pass)
df_pass_scaled = pd.DataFrame(pass_scaled, index=df_pass.index,columns = df_pass.columns)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vvif = pd.DataFrame()
vvif["VIF Factor"] = [variance_inflation_factor(df_pass_scaled.values,i) for i in range(df_pass_scaled.shape[1])]
vvif["features"] = df_pass_scaled.columns
vvvif = vvif[vvif['VIF Factor']>=5]
vvvif
# Out:
#     VIF Factor features
# 8     6.104147     X_10
# 9     6.101362     X_11
# 11   22.763332     X_13
# 12   24.321172     X_14
# 13   11.214018     X_15
# 14    5.137648     X_16
# 15   22.668623     X_17
# 16   14.701192     X_18
# 17    5.268589     X_19
# 18    5.284368     X_20
# 19    5.588047     X_21
# 20    5.124644     X_22
# 39    9.398721     X_42
# 40    8.462547     X_43
# 42   11.795441     X_45

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
nonpass_scaled = scaler.fit_transform(df_nonpass)
df_nonpass_scaled = pd.DataFrame(nonpass_scaled, index=df_nonpass.index,columns = df_nonpass.columns)

# %%
vvif = pd.DataFrame()
vvif["VIF Factor"] = [variance_inflation_factor(df_nonpass_scaled.values,i) for i in range(df_nonpass_scaled.shape[1])]
vvif["features"] = df_nonpass_scaled.columns
vvvif = vvif[vvif['VIF Factor']>=5]
vvvif
# Out:
#     VIF Factor features
# 11   28.816197     X_13
# 12   29.049337     X_14
# 13   11.222021     X_15
# 14    5.404564     X_16
# 15   27.543070     X_17
# 16   14.521956     X_18
# 17    5.515156     X_19
# 18    5.484732     X_20
# 19    6.107253     X_21
# 20    5.248468     X_22
# 26    9.833609     X_29
# 39   12.600210     X_42
# 40    9.753763     X_43
# 42   15.245145     X_45
# 53   11.665277     X_61
